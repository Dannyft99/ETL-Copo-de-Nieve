# %%
import pandas as pd
import numpy as np 
from sqlalchemy import create_engine
from sqlalchemy import Table, Column, Integer, String, MetaData, ForeignKey
from sqlalchemy import inspect
from sqlalchemy import MetaData
import sqlite3
import datetime

# %%
#pip install pyodbc

# %%
engine = create_engine('sqlite:///Northwind_large.sqlite') #creación de la conexión con la bdd

# %%
frameAlbums = pd.read_sql_query("""SELECT  * from Customer; """, con=engine.connect())
frameAlbums
# Out:
#        Id                         CompanyName  ...           Phone             Fax
# 0   ALFKI                 Alfreds Futterkiste  ...     030-0074321     030-0076545
# 1   ANATR  Ana Trujillo Emparedados y helados  ...    (5) 555-4729    (5) 555-3745
# 2   ANTON             Antonio Moreno Taquería  ...    (5) 555-3932            None
# 3   AROUT                     Around the Horn  ...  (171) 555-7788  (171) 555-6750
# 4   BERGS                  Berglunds snabbköp  ...   0921-12 34 65   0921-12 34 67
# ..    ...                                 ...  ...             ...             ...
# 86  WARTH                      Wartian Herkku  ...      981-443655      981-443655
# 87  WELLI              Wellington Importadora  ...   (14) 555-8122            None
# 88  WHITC                White Clover Markets  ...  (206) 555-4112  (206) 555-4115
# 89  WILMK                         Wilman Kala  ...     90-224 8858     90-224 8858
# 90  WOLZA                      Wolski  Zajazd  ...   (26) 642-7012   (26) 642-7012
#
# [91 rows x 11 columns]

# %% [markdown]
# EXTRACCION

# %%
metadata = MetaData()
metadata.create_all(engine)
inspector = inspect(engine)
inspector.get_columns('Customer')
# Out:
# [{'autoincrement': 'auto',
#   'default': None,
#   'name': 'Id',
#   'nullable': True,
#   'primary_key': 1,
#   'type': VARCHAR(length=8000)},
#  {'autoincrement': 'auto',
#   'default': None,
#   'name': 'CompanyName',
#   'nullable': True,
#   'primary_key': 0,
#   'type': VARCHAR(length=8000)},
#  {'autoincrement': 'auto',
#   'default': None,
#   'name': 'ContactName',
#   'nullable': True,
#   'primary_key': 0,
#   'type': VARCHAR(length=8000)},
#  {'autoincrement': 'auto',
#   'default': None,
#   'name': 'ContactTitle',
#   'nullable': True,
#   'primary_key': 0,
#   'type': VARCHAR(length=8000)},
#  {'autoincrement': 'auto',
#   'default': None,
#   'name': 'Address',
#   'nullable': True,
#   'primary_key': 0,
#   'type': VARCHAR(length=8000)},
#  {'autoincrement': 'auto',
#   'default': None,
#   'name': 'City',
#   'nullable': True,
#   'primary_key': 0,
#   'type': VARCHAR(length=8000)},
#  {'autoincrement': 'auto',
#   'default': None,
#   'name': 'Region',
#   'nullable': True,
#   'primary_key': 0,
#   'type': VARCHAR(length=8000)},
#  {'autoincrement': 'auto',
#   'default': None,
#   'name': 'PostalCode',
#   'nullable': True,
#   'primary_key': 0,
#   'type': VARCHAR(length=8000)},
#  {'autoincrement': 'auto',
#   'default': None,
#   'name': 'Country',
#   'nullable': True,
#   'primary_key': 0,
#   'type': VARCHAR(length=8000)},
#  {'autoincrement': 'auto',
#   'default': None,
#   'name': 'Phone',
#   'nullable': True,
#   'primary_key': 0,
#   'type': VARCHAR(length=8000)},
#  {'autoincrement': 'auto',
#   'default': None,
#   'name': 'Fax',
#   'nullable': True,
#   'primary_key': 0,
#   'type': VARCHAR(length=8000)}]

# %% [markdown]
# TRASFORMAR

# %%
df_customer = pd.read_sql_query(
"""
SELECT 
    CompanyName,  
    ContactName,  
    ContactTitle, 
    Address,      
    City,         
    Region,     
    ifnull(PostalCode ,'No Asigando')as PostalCode,
    replace(replace(Country,"UK","United Kingdom"),"USA","The United States of America") as Country, 
    Phone,
    Fax            
FROM Customer;
"""
,con=engine.connect())
df_customer.head(8)
# Out:
#                           CompanyName  ...             Fax
# 0                 Alfreds Futterkiste  ...     030-0076545
# 1  Ana Trujillo Emparedados y helados  ...    (5) 555-3745
# 2             Antonio Moreno Taquería  ...            None
# 3                     Around the Horn  ...  (171) 555-6750
# 4                  Berglunds snabbköp  ...   0921-12 34 67
# 5             Blauer See Delikatessen  ...      0621-08924
# 6            Blondesddsl père et fils  ...     88.60.15.32
# 7           Bólido Comidas preparadas  ...  (91) 555 91 99
#
# [8 rows x 10 columns]

# %%
df_employe = pd.read_sql_query(
"""
SELECT 
    LastName,
    FirstName,       
    Title,         
    TitleOfCourtesy, 
    BirthDate  ,    
    HireDate ,      
    Address,        
    City  ,         
    Region,        
    PostalCode,      
    replace(replace(Country,"UK","United Kingdom"),"USA","The United States of America") as Country,        
    HomePhone,      
    Extension,       
    ifnull(Photo ,'No Asigando')as Photo,             
    Notes,          
    ifnull(ReportsTo ,'No Asigando')as ReportsTo,          
    PhotoPath             
FROM Employee;
"""
,con=engine.connect())
df_employe.head(4)
# Out:
#     LastName FirstName  ...    ReportsTo                               PhotoPath
# 0    Davolio     Nancy  ...            2    http://accweb/emmployees/davolio.bmp
# 1     Fuller    Andrew  ...  No Asigando     http://accweb/emmployees/fuller.bmp
# 2  Leverling     Janet  ...            2  http://accweb/emmployees/leverling.bmp
# 3    Peacock  Margaret  ...            2    http://accweb/emmployees/peacock.bmp
#
# [4 rows x 17 columns]

# %%
df_location = pd.read_sql_query(
"""
SELECT  
    ShipName,
    ShipAddress,   
    ShipCity  ,    
    ShipRegion ,    
    ifnull(ShipPostalCode ,'No Asigando')as ShipPostalCode,     
    replace(replace(ShipCountry,"UK","United Kingdom"),"USA","The United States of America") as ShipCountry              
                   
FROM Orders;
"""
,con=engine.connect())
df_location.head(4)
# Out:
#                     ShipName         ShipAddress  ... ShipPostalCode ShipCountry
# 0  Vins et alcools Chevalier  59 rue de l'Abbaye  ...          51100      France
# 1         Toms Spezialitäten       Luisenstr. 48  ...          44087     Germany
# 2              Hanari Carnes     Rua do Paço, 67  ...      05454-876      Brazil
# 3       Victuailles en stock  2, rue du Commerce  ...          69004      France
#
# [4 rows x 6 columns]

# %%
df_produc = pd.read_sql_query(
"""
SELECT 
   
    ProductName,
    SupplierId,
    CategoryId,                              
    QuantityPerUnit, 
    UnitPrice,      
    UnitsInStock,    
    UnitsOnOrder,   
    ReorderLevel,   
    Discontinued      
                  
FROM Product;
"""
,con=engine.connect())
df_produc.head(4)
# Out:
#                     ProductName  SupplierId  ...  ReorderLevel Discontinued
# 0                          Chai           1  ...            10            0
# 1                         Chang           1  ...            25            0
# 2                 Aniseed Syrup           1  ...            25            0
# 3  Chef Anton's Cajun Seasoning           2  ...             0            0
#
# [4 rows x 9 columns]

# %%
df_shipper = pd.read_sql_query(
"""
SELECT Id As shipperId,
                
    CompanyName,
    Phone      
                  
FROM Shipper;

"""
,con=engine.connect())
df_shipper.head(4)
# Out:
#    shipperId       CompanyName           Phone
# 0          1    Speedy Express  (503) 555-9831
# 1          2    United Package  (503) 555-3199
# 2          3  Federal Shipping  (503) 555-9931

# %%
df_supplier = pd.read_sql_query(
"""
SELECT 
                
    CompanyName ,
    ContactName  ,
    ContactTitle ,
    Address      ,
    City        ,
    Region      ,
    PostalCode  ,
    replace(replace(Country,"UK","United Kingdom"),"USA","The United States of America") as Country ,           
    ifnull(Fax ,'No Asigando')as Fax,
    ifnull(HomePage ,'No Asigando')as HomePage,         
    Phone    
    FROM supplier;
"""
,con=engine.connect())
df_supplier.head(4)
# Out:
#                   CompanyName       ContactName  ...     HomePage           Phone
# 0              Exotic Liquids  Charlotte Cooper  ...  No Asigando  (171) 555-2222
# 1  New Orleans Cajun Delights     Shelley Burke  ...  #CAJUN.HTM#  (100) 555-4822
# 2   Grandma Kelly's Homestead     Regina Murphy  ...  No Asigando  (313) 555-5735
# 3               Tokyo Traders      Yoshi Nagase  ...  No Asigando  (03) 3555-5011
#
# [4 rows x 11 columns]

# %%
fecha_inicio='2009-01-01'
fecha_fin='2030-12-31'
dataFrameDate = pd.DataFrame({'fecha': pd.date_range(fecha_inicio, fecha_fin)})
dataFrameDate['año'] = dataFrameDate.fecha.dt.year
dataFrameDate['mes'] = dataFrameDate.fecha.dt.month
dataFrameDate['dia'] = dataFrameDate.fecha.dt.day
dataFrameDate['nombre_dia'] = dataFrameDate.fecha.dt.day_name()
dataFrameDate['dia_semana'] = dataFrameDate.fecha.dt.dayofweek
dataFrameDate['semana'] = dataFrameDate.fecha.dt.weekofyear
dataFrameDate['trimestre'] = dataFrameDate.fecha.dt.quarter
dataFrameDate = dataFrameDate[['fecha', 'año', 'mes', 'dia', 'nombre_dia', 'dia_semana', 'semana', 'trimestre']] 
dataFrameDate
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   if __name__ == '__main__':
#           fecha   año  mes  dia nombre_dia  dia_semana  semana  trimestre
# 0    2009-01-01  2009    1    1   Thursday           3       1          1
# 1    2009-01-02  2009    1    2     Friday           4       1          1
# 2    2009-01-03  2009    1    3   Saturday           5       1          1
# 3    2009-01-04  2009    1    4     Sunday           6       1          1
# 4    2009-01-05  2009    1    5     Monday           0       2          1
# ...         ...   ...  ...  ...        ...         ...     ...        ...
# 8030 2030-12-27  2030   12   27     Friday           4      52          4
# 8031 2030-12-28  2030   12   28   Saturday           5      52          4
# 8032 2030-12-29  2030   12   29     Sunday           6      52          4
# 8033 2030-12-30  2030   12   30     Monday           0       1          4
# 8034 2030-12-31  2030   12   31    Tuesday           1       1          4
#
# [8035 rows x 8 columns]

# %% [markdown]
# Tabla de hechos

# %%
TablaHechos = pd.read_sql_query(
"""   
SELECT OrderDetail.Id AS FactId ,Customer.Id AS CustomerId, Employee.Id AS EmployeeId, Orders.Id AS LocationId, Orders.OrderDate,Product.Id AS ProductId , Shipper.Id AS ShipperId, Supplier.Id AS SupplierId, OrderDetail.UnitPrice
FROM OrderDetail
 INNER JOIN Orders  ON Orders.Id = OrderDetail.OrderId 
INNER JOIN  Customer ON Customer.Id = Orders.CustomerId 
INNER JOIN Employee  ON Employee.Id = Orders.EmployeeId
INNER JOIN Product  ON Product.Id = OrderDetail.ProductId
 INNER JOIN Shipper  ON Shipper.Id = Orders.ShipVia 
 INNER JOIN Supplier ON Supplier.Id = Product.SupplierId ;
"""
,con=engine.connect())
TablaHechos.head(4)
# Out:
#      FactId CustomerId  EmployeeId  ...  ShipperId SupplierId  UnitPrice
# 0  10248/11      VINET           5  ...          3          5       14.0
# 1  10248/42      VINET           5  ...          3         20        9.8
# 2  10248/72      VINET           5  ...          3         14       34.8
# 3  10249/14      TOMSP           6  ...          1          6       18.6
#
# [4 rows x 9 columns]

# %% [markdown]
# carga de datos

# %%
con2 = create_engine('sqlite:///DW_Northwind_Estrella.db')
con2
# Out:
# Engine(sqlite:///DW_Northwind_Estrella.db)

# %%
def updateData(name_table,data_db,name_columns):
	print(name_columns)
	aux_values='?'
	aux_data=[]
	aux_columns=name_columns[0]
	aux_data.append(list(data_db[name_columns[0]]))
	entities=[]
	aux_entities=[]
	for i in range(len(name_columns)-1):
		aux_values+=',?'
		aux_columns+=','+name_columns[i+1]
		aux_data.append(list(data_db[name_columns[i+1]]))
	for i in range(len(aux_data[0])):
		for j in range(len(aux_data)):
			aux_entities.append(aux_data[j][i])
		entities.append(aux_entities)
		aux_entities=[]
	with con2.connect() as con:
		for i in entities:
			con.execute('INSERT INTO '+name_table+'('+aux_columns+') VALUES('+aux_values+')', i)
	con.close()

# %%
updateData('dim_customers',df_customer,list(df_customer.columns.values))
# Out:
# ['CompanyName', 'ContactName', 'ContactTitle', 'Address', 'City', 'Region', 'PostalCode', 'Country', 'Phone', 'Fax']
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1802                     self.dialect.do_execute(
# -> 1803                         cursor, statement, parameters, context
#    1804                     )
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#
# IntegrityError: NOT NULL constraint failed: dim_customers.Fax
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-22-653c36e36bc8> in <module>()
#       1
# ----> 2 updateData('dim_customers',df_customer,list(df_customer.columns.values))
#       3
#       4
#
# <ipython-input-21-aa8f3440b769> in updateData(name_table, data_db, name_columns)
#      18         with con2.connect() as con:
#      19                 for i in entities:
# ---> 20                         con.execute('INSERT INTO '+name_table+'('+aux_columns+') VALUES('+aux_values+')', i)
#      21         con.close()
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1277                 params,
#    1278                 _EMPTY_EXECUTION_OPTS,
# -> 1279                 future=False,
#    1280             )
#    1281
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1583             execution_options,
#    1584             statement,
# -> 1585             distilled_parameters,
#    1586         )
#    1587
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844         except BaseException as e:
#    1845             self._handle_dbapi_exception(
# -> 1846                 e, statement, parameters, cursor, context
#    1847             )
#    1848
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2025             elif should_wrap:
#    2026                 util.raise_(
# -> 2027                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2028                 )
#    2029             else:
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1801                 if not evt_handled:
#    1802                     self.dialect.do_execute(
# -> 1803                         cursor, statement, parameters, context
#    1804                     )
#    1805
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     730
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#     734     def do_execute_no_params(self, cursor, statement, context=None):
#
# IntegrityError: (sqlite3.IntegrityError) NOT NULL constraint failed: dim_customers.Fax
# [SQL: INSERT INTO dim_customers(CompanyName,ContactName,ContactTitle,Address,City,Region,PostalCode,Country,Phone,Fax) VALUES(?,?,?,?,?,?,?,?,?,?)]
# [parameters: ('Antonio Moreno Taquería', 'Antonio Moreno', 'Owner', 'Mataderos  2312', 'México D.F.', 'Central America', '05023', 'Mexico', '(5) 555-3932', None)]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
updateData('dim_location',df_location,list(df_location.columns.values))
# Out:
# ['ShipName', 'ShipAddress', 'ShipCity', 'ShipRegion', 'ShipPostalCode', 'ShipCountry']

# %%
updateData('dim_employees',df_employe ,list(df_employe.columns.values))
# Out:
# ['LastName', 'FirstName', 'Title', 'TitleOfCourtesy', 'BirthDate', 'HireDate', 'Address', 'City', 'Region', 'PostalCode', 'Country', 'HomePhone', 'Extension', 'Photo', 'Notes', 'ReportsTo', 'PhotoPath']
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1802                     self.dialect.do_execute(
# -> 1803                         cursor, statement, parameters, context
#    1804                     )
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#
# OperationalError: table dim_employees has no column named ReportsTo
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-24-889d0854c04e> in <module>()
#       1
# ----> 2 updateData('dim_employees',df_employe ,list(df_employe.columns.values))
#       3
#
# <ipython-input-21-aa8f3440b769> in updateData(name_table, data_db, name_columns)
#      18         with con2.connect() as con:
#      19                 for i in entities:
# ---> 20                         con.execute('INSERT INTO '+name_table+'('+aux_columns+') VALUES('+aux_values+')', i)
#      21         con.close()
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1277                 params,
#    1278                 _EMPTY_EXECUTION_OPTS,
# -> 1279                 future=False,
#    1280             )
#    1281
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1583             execution_options,
#    1584             statement,
# -> 1585             distilled_parameters,
#    1586         )
#    1587
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844         except BaseException as e:
#    1845             self._handle_dbapi_exception(
# -> 1846                 e, statement, parameters, cursor, context
#    1847             )
#    1848
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2025             elif should_wrap:
#    2026                 util.raise_(
# -> 2027                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2028                 )
#    2029             else:
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1801                 if not evt_handled:
#    1802                     self.dialect.do_execute(
# -> 1803                         cursor, statement, parameters, context
#    1804                     )
#    1805
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     730
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#     734     def do_execute_no_params(self, cursor, statement, context=None):
#
# OperationalError: (sqlite3.OperationalError) table dim_employees has no column named ReportsTo
# [SQL: INSERT INTO dim_employees(LastName,FirstName,Title,TitleOfCourtesy,BirthDate,HireDate,Address,City,Region,PostalCode,Country,HomePhone,Extension,Photo,Notes,ReportsTo,PhotoPath) VALUES(?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)]
# [parameters: ('Davolio', 'Nancy', 'Sales Representative', 'Ms.', '1980-12-08', '2024-05-01', '507 - 20th Ave. E. Apt. 2A', 'Seattle', 'North America', '98122', 'The United States of America', '(206) 555-9857', '5467', 'No Asigando', "Education includes a BA in psychology from Colorado State University in 1970.  She also completed 'The Art of the Cold Call.'  Nancy is a member of Toastmasters International.", 2, 'http://accweb/emmployees/davolio.bmp')]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
updateData('dim_products',df_produc,list(df_produc.columns.values))
# Out:
# ['ProductName', 'SupplierId', 'CategoryId', 'QuantityPerUnit', 'UnitPrice', 'UnitsInStock', 'UnitsOnOrder', 'ReorderLevel', 'Discontinued']
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1802                     self.dialect.do_execute(
# -> 1803                         cursor, statement, parameters, context
#    1804                     )
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#
# OperationalError: table dim_products has no column named SupplierId
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-84-0a9775ada5f7> in <module>()
# ----> 1 updateData('dim_products',df_produc,list(df_produc.columns.values))
#
# <ipython-input-71-aa8f3440b769> in updateData(name_table, data_db, name_columns)
#      18         with con2.connect() as con:
#      19                 for i in entities:
# ---> 20                         con.execute('INSERT INTO '+name_table+'('+aux_columns+') VALUES('+aux_values+')', i)
#      21         con.close()
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1277                 params,
#    1278                 _EMPTY_EXECUTION_OPTS,
# -> 1279                 future=False,
#    1280             )
#    1281
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1583             execution_options,
#    1584             statement,
# -> 1585             distilled_parameters,
#    1586         )
#    1587
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844         except BaseException as e:
#    1845             self._handle_dbapi_exception(
# -> 1846                 e, statement, parameters, cursor, context
#    1847             )
#    1848
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2025             elif should_wrap:
#    2026                 util.raise_(
# -> 2027                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2028                 )
#    2029             else:
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1801                 if not evt_handled:
#    1802                     self.dialect.do_execute(
# -> 1803                         cursor, statement, parameters, context
#    1804                     )
#    1805
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     730
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#     734     def do_execute_no_params(self, cursor, statement, context=None):
#
# OperationalError: (sqlite3.OperationalError) table dim_products has no column named SupplierId
# [SQL: INSERT INTO dim_products(ProductName,SupplierId,CategoryId,QuantityPerUnit,UnitPrice,UnitsInStock,UnitsOnOrder,ReorderLevel,Discontinued) VALUES(?,?,?,?,?,?,?,?,?)]
# [parameters: ('Chai', 1, 1, '10 boxes x 20 bags', 18.0, 39, 0, 10, 0)]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
updateData('dim_shipper',df_shipper,list(df_shipper.columns.values))
# Out:
# ['shipperId', 'CompanyName', 'Phone']

# %%
updateData('dim_Supplier',df_supplier,list(df_supplier.columns.values))
# Out:
# ['CompanyName', 'ContactName', 'ContactTitle', 'Address', 'City', 'Region', 'PostalCode', 'Country', 'Fax', 'HomePage', 'Phone']
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1802                     self.dialect.do_execute(
# -> 1803                         cursor, statement, parameters, context
#    1804                     )
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#
# OperationalError: table dim_Supplier has no column named City
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-89-f859aeb4a378> in <module>()
# ----> 1 updateData('dim_Supplier',df_supplier,list(df_supplier.columns.values))
#
# <ipython-input-71-aa8f3440b769> in updateData(name_table, data_db, name_columns)
#      18         with con2.connect() as con:
#      19                 for i in entities:
# ---> 20                         con.execute('INSERT INTO '+name_table+'('+aux_columns+') VALUES('+aux_values+')', i)
#      21         con.close()
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1277                 params,
#    1278                 _EMPTY_EXECUTION_OPTS,
# -> 1279                 future=False,
#    1280             )
#    1281
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1583             execution_options,
#    1584             statement,
# -> 1585             distilled_parameters,
#    1586         )
#    1587
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844         except BaseException as e:
#    1845             self._handle_dbapi_exception(
# -> 1846                 e, statement, parameters, cursor, context
#    1847             )
#    1848
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2025             elif should_wrap:
#    2026                 util.raise_(
# -> 2027                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2028                 )
#    2029             else:
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1801                 if not evt_handled:
#    1802                     self.dialect.do_execute(
# -> 1803                         cursor, statement, parameters, context
#    1804                     )
#    1805
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     730
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#     734     def do_execute_no_params(self, cursor, statement, context=None):
#
# OperationalError: (sqlite3.OperationalError) table dim_Supplier has no column named City
# [SQL: INSERT INTO dim_Supplier(CompanyName,ContactName,ContactTitle,Address,City,Region,PostalCode,Country,Fax,HomePage,Phone) VALUES(?,?,?,?,?,?,?,?,?,?,?)]
# [parameters: ('Exotic Liquids', 'Charlotte Cooper', 'Purchasing Manager', '49 Gilbert St.', 'London', 'British Isles', 'EC1 4SD', 'United Kingdom', 'No Asigando', 'No Asigando', '(171) 555-2222')]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
dataFrameDate.to_sql(name='dim_time', con=engine.connect(), if_exists='append',index=False)
print()

# %%
updateData('Order_Vent',TablaHechos,list(TablaHechos.columns.values))
# Out:
# ['FactId', 'CustomerId', 'EmployeeId', 'LocationId', 'OrderDate', 'ProductId', 'ShipperId', 'SupplierId', 'UnitPrice']
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1802                     self.dialect.do_execute(
# -> 1803                         cursor, statement, parameters, context
#    1804                     )
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#
# OperationalError: table Order_Vent has no column named FactId
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-93-359f79742db1> in <module>()
# ----> 1 updateData('Order_Vent',TablaHechos,list(TablaHechos.columns.values))
#
# <ipython-input-71-aa8f3440b769> in updateData(name_table, data_db, name_columns)
#      18         with con2.connect() as con:
#      19                 for i in entities:
# ---> 20                         con.execute('INSERT INTO '+name_table+'('+aux_columns+') VALUES('+aux_values+')', i)
#      21         con.close()
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1277                 params,
#    1278                 _EMPTY_EXECUTION_OPTS,
# -> 1279                 future=False,
#    1280             )
#    1281
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1583             execution_options,
#    1584             statement,
# -> 1585             distilled_parameters,
#    1586         )
#    1587
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844         except BaseException as e:
#    1845             self._handle_dbapi_exception(
# -> 1846                 e, statement, parameters, cursor, context
#    1847             )
#    1848
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2025             elif should_wrap:
#    2026                 util.raise_(
# -> 2027                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2028                 )
#    2029             else:
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1801                 if not evt_handled:
#    1802                     self.dialect.do_execute(
# -> 1803                         cursor, statement, parameters, context
#    1804                     )
#    1805
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     730
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#     734     def do_execute_no_params(self, cursor, statement, context=None):
#
# OperationalError: (sqlite3.OperationalError) table Order_Vent has no column named FactId
# [SQL: INSERT INTO Order_Vent(FactId,CustomerId,EmployeeId,LocationId,OrderDate,ProductId,ShipperId,SupplierId,UnitPrice) VALUES(?,?,?,?,?,?,?,?,?)]
# [parameters: ('10248/11', 'VINET', 5, 10248, '2012-07-04', 11, 3, 5, 14.0)]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
